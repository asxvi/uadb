# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from typing import List
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
def load_all_csvs(csv_paths: List[str]) -> pd.DataFrame:
        """Load and combine multiple experiment CSVs."""
        dfs = []
        for path in csv_paths:
            df = pd.read_csv(path, index_col=0)
            df['source_file'] = Path(path).parent.name  # track which experiment it came from
            dfs.append(df)

            combined = pd.concat(dfs, ignore_index=True)
                
        return combined

# %%
# future data
['data/results/2330814086/ni_gap_10k/ni_gap_red1_1_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red2_2_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red3_3_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red4_4_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red5_5_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red6_6_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red7_7_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red8_8_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red9_9_sweep//results_sd2330814086.csv', 'data/results/2330814086/ni_gap_10k/ni_gap_red10_10_sweep//results_sd2330814086.csv']
# Out:
# ['data/results/2330814086/ni_gap_10k/ni_gap_red1_1_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red2_2_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red3_3_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red4_4_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red5_5_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red6_6_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red7_7_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red8_8_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red9_9_sweep//results_sd2330814086.csv',
#  'data/results/2330814086/ni_gap_10k/ni_gap_red10_10_sweep//results_sd2330814086.csv']

# %%
paths = ['data/results/2331775200/ni_gap_10k/ni10_red1_1_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red2_2_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red3_3_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red4_4_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red5_5_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red6_6_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red7_7_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red8_8_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red9_9_sweep//results_sd2331775200.csv', 'data/results/2331775200/ni_gap_10k/ni10_red10_10_sweep//results_sd2331775200.csv']
df = load_all_csvs(paths)
df['gap_size_range_tuple'] = df['gap_size_range'].apply(ast.literal_eval)
df['reduce_triggerSz_sizeLim_tuple'] = df['reduce_triggerSz_sizeLim'].apply(ast.literal_eval)
df
# Out:
#     master_seed data_type  num_trials  dataset_size  uncertain_ratio  \
# 0    2331775200       set           5         10000              0.0
# 1    2331775200       set           5         10000              0.0
# 2    2331775200       set           5         10000              0.0
# 3    2331775200       set           5         10000              0.0
# 4    2331775200       set           5         10000              0.0
# ..          ...       ...         ...           ...              ...
# 95   2331775200       set           5         10000              0.0
# 96   2331775200       set           5         10000              0.0
# 97   2331775200       set           5         10000              0.0
# 98   2331775200       set           5         10000              0.0
# 99   2331775200       set           5         10000              0.0
#
#    interval_size_range mult_size_range  num_intervals  gap_size  \
# 0           (1, 50000)          (1, 5)              1       NaN
# 1           (1, 50000)          (1, 5)              2       NaN
# 2           (1, 50000)          (1, 5)              3       NaN
# 3           (1, 50000)          (1, 5)              4       NaN
# 4           (1, 50000)          (1, 5)              5       NaN
# ..                 ...             ...            ...       ...
# 95          (1, 50000)          (1, 5)              6       NaN
# 96          (1, 50000)          (1, 5)              7       NaN
# 97          (1, 50000)          (1, 5)              8       NaN
# 98          (1, 50000)          (1, 5)              9       NaN
# 99          (1, 50000)          (1, 5)             10       NaN
#
#     interval_width  num_intervals_range gap_size_range interval_width_range  \
# 0              NaN                  NaN   (1000, 5000)              (2, 15)
# 1              NaN                  NaN   (1000, 5000)              (2, 15)
# 2              NaN                  NaN   (1000, 5000)              (2, 15)
# 3              NaN                  NaN   (1000, 5000)              (2, 15)
# 4              NaN                  NaN   (1000, 5000)              (2, 15)
# ..             ...                  ...            ...                  ...
# 95             NaN                  NaN   (1000, 5000)              (2, 15)
# 96             NaN                  NaN   (1000, 5000)              (2, 15)
# 97             NaN                  NaN   (1000, 5000)              (2, 15)
# 98             NaN                  NaN   (1000, 5000)              (2, 15)
# 99             NaN                  NaN   (1000, 5000)              (2, 15)
#
#    reduce_triggerSz_sizeLim independent_variable  min_time_mean  min_time_std  \
# 0                    (1, 1)        num_intervals         9.5966      0.961806
# 1                    (1, 1)        num_intervals        12.3710      0.594433
# 2                    (1, 1)        num_intervals        19.4802      3.472764
# 3                    (1, 1)        num_intervals        27.9266      2.067404
# 4                    (1, 1)        num_intervals        58.9176     50.277915
# ..                      ...                  ...            ...           ...
# 95                 (10, 10)        num_intervals        38.1866      1.149044
# 96                 (10, 10)        num_intervals        46.0168      1.142016
# 97                 (10, 10)        num_intervals        57.7866      5.890623
# 98                 (10, 10)        num_intervals        62.1324      1.015518
# 99                 (10, 10)        num_intervals        70.7672      2.417206
#
#     max_time_mean  max_time_std  sum_time_mean  sum_time_std  \
# 0          9.7094      0.801849         7.0954      1.576297
# 1         14.0118      2.070650         9.7758      3.889095
# 2         15.8060      1.218773         8.4676      0.341218
# 3         20.6010      3.526074        10.2800      1.474675
# 4         39.3646     34.100180        10.3306      0.387858
# ..            ...           ...            ...           ...
# 95        24.1386      1.214425        69.5466      2.549849
# 96        26.0130      0.343492        88.4360      1.161783
# 97        29.0384      0.586718       110.2898      4.366861
# 98        32.7328      0.910117       132.9182      2.750958
# 99        35.4536      2.095144       160.0870      1.373264
#
#     sumtest_time_mean  sumtest_time_std  reduce_calls_mean  \
# 0              6.6670          0.365360             9999.0
# 1              7.9946          0.685345             9999.0
# 2              9.6512          1.769269             9999.0
# 3             11.7194          3.691829             9999.0
# 4             10.8108          0.224047             9999.0
# ..                ...               ...                ...
# 95            69.5572          2.441153             9999.0
# 96            87.9014          1.840875             9999.0
# 97           109.2170          1.413796             9999.0
# 98           157.4932         45.389212             9999.0
# 99           161.3956          4.317562             9999.0
#
#     max_interval_count_mean  total_interval_count_mean  combine_calls_mean  \
# 0                       1.0                    10000.0             10000.0
# 1                       4.0                    20002.0             10000.0
# 2                       9.0                    30006.0             10000.0
# 3                      16.0                    40012.0             10000.0
# 4                      25.0                    50020.0             10000.0
# ..                      ...                        ...                 ...
# 95                     60.0                   599922.0             10000.0
# 96                     70.0                   699916.0             10000.0
# 97                     80.0                   799912.0             10000.0
# 98                     90.0                   899910.0             10000.0
# 99                    100.0                   999910.0             10000.0
#
#     result_size_mean  result_coverage_mean          source_file  \
# 0                1.0           272323330.0    ni10_red1_1_sweep
# 1                1.0            30233544.2    ni10_red1_1_sweep
# 2                1.0            60290523.0    ni10_red1_1_sweep
# 3                1.0            90344704.8    ni10_red1_1_sweep
# 4                1.0           120458149.6    ni10_red1_1_sweep
# ..               ...                   ...                  ...
# 95              10.0           151265620.0  ni10_red10_10_sweep
# 96              10.0           181252391.4  ni10_red10_10_sweep
# 97              10.0           211302076.4  ni10_red10_10_sweep
# 98              10.0           241509711.2  ni10_red10_10_sweep
# 99              10.0           271400929.8  ni10_red10_10_sweep
#
#    gap_size_range_tuple reduce_triggerSz_sizeLim_tuple
# 0          (1000, 5000)                         (1, 1)
# 1          (1000, 5000)                         (1, 1)
# 2          (1000, 5000)                         (1, 1)
# 3          (1000, 5000)                         (1, 1)
# 4          (1000, 5000)                         (1, 1)
# ..                  ...                            ...
# 95         (1000, 5000)                       (10, 10)
# 96         (1000, 5000)                       (10, 10)
# 97         (1000, 5000)                       (10, 10)
# 98         (1000, 5000)                       (10, 10)
# 99         (1000, 5000)                       (10, 10)
#
# [100 rows x 32 columns]

# %%
reds = sorted(df["reduce_triggerSz_sizeLim_tuple"].unique())
n = len(reds)

fig, ax = plt.subplots(1, n, figsize=(6*n, 10), sharey=True)
for i, red in enumerate(reds):
    ax_time = ax[i]
    subdf = df[df["reduce_triggerSz_sizeLim_tuple"] == red]
    
    pivot = subdf.pivot_table(
        values="sum_time_mean",
        index="num_intervals",
        columns="gap_size_range"
    )
    pivot.sort_index(axis=0)
    sns.heatmap(pivot, ax=ax_time, cmap="RdYlGn_r", cbar=False)
    ax_time.set_title(f"Reduction {red}")
    ax_time.set_xlabel("Gap Size")

    # ax_cov = ax[i]
    # pivot_cov = subdf.pivot_table(
    #     values="result_coverage_mean",
    #     index="num_intervals",
    #     columns="gap_size_range"
    # )
    # pivot_cov.sort_index(axis=0)
    # sns.heatmap(pivot_cov, ax=ax_cov, cmap="Blues", cbar=False)
    # ax_cov.set_xlabel("Gap Size")

plt.tight_layout()

# %%
reds = sorted(df['reduce_triggerSz_sizeLim_tuple'].unique())
x_labels = [str(r) for r in reduce_params] 

plt.figure(figsize=(6,6))
fig, ax = plt.subplots(1, 1, sharey=True)

for ni in sorted(df['num_intervals'].unique()):
    df_ni = df[df['num_intervals'] == ni]
    
    # Sort by reduce tuple
    df_ni = df_ni.set_index('reduce_triggerSz_sizeLim_tuple').reindex(reduce_params).reset_index()
    y = df_ni['sum_time_mean']
    plt.plot(x_labels, y, marker='o', label=f'ni={ni}')

plt.xlabel("Reduce tuple")
plt.ylabel("Execution time (s)")
plt.title("Execution time vs Reduce tuple for each Number of Intervals")
plt.xticks(rotation=45)
plt.legend(title="num_intervals")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
reduce_params = sorted(df['reduce_triggerSz_sizeLim_tuple'].unique())
x_labels = [str(r) for r in reduce_params]
n = len(df['num_intervals'].unique())

fig, axes=  plt.subplots(3, n, figsize=(6*n,12))
for i, ni in enumerate(sorted(df['num_intervals'].unique())):
    # plot for each ni
    df_ni = df[df['num_intervals'] == ni].copy()

    # PLot 1: time
    ax = axes[0, i]
    y = df_ni['sum_time_mean']
    ax.plot(x_labels, y, marker='o')
    ax.set_title(f'ni={ni}')
    ax.set_xlabel('red')
    ax.grid(True)

    # Plot 2: coverage
    ax = axes[1, i]
    y = df_ni['result_coverage_mean']
    ax.plot(x_labels, y, marker='o')
    ax.set_title(f'ni={ni}')
    ax.set_xlabel('red')
    ax.grid(True)

    # Plot 3: sq distance of both time and coverage
    # normalize time and coverage
    df_ni['time_norm'] = (
        (df_ni['sum_time_mean'] - df_ni['sum_time_mean'].min()) /
        (df_ni['sum_time_mean'].max() - df_ni['sum_time_mean'].min())
    )
    df_ni['cov_norm'] = (
        (df_ni['result_coverage_mean'] - df_ni['result_coverage_mean'].min()) /
        (df_ni['result_coverage_mean'].max() - df_ni['result_coverage_mean'].min())
    )
    scores = (df_ni['time_norm']**2 + df_ni['cov_norm']**2)**0.5
    
    ax = axes[2, i]
    ax.plot(x_labels, scores, marker='o')
    ax.set_title(f'ni={ni}')
    ax.set_xlabel('red')
    ax.grid(True)
    
axes[0][0].set_ylabel('Time (ms)')
axes[1][0].set_ylabel('Coverage (smaller=better)')
axes[2][0].set_ylabel('Distance (smaller=bettwe)')
plt.tight_layout()
plt.savefig('./graphics/cover_U_shape_with_ni.jpg')
plt.show()

# %%
paths = ['data/results/2415844636/ni_gap_sweep_n10k/ni_gap_red3_1_sweep//results_sd2415844636.csv']
df = load_all_csvs(paths)
df['gap_size_range_tuple'] = df['gap_size_range'].apply(ast.literal_eval)
df['reduce_triggerSz_sizeLim_tuple'] = df['reduce_triggerSz_sizeLim'].apply(ast.literal_eval)
df
# Out:
#     master_seed data_type  num_trials  dataset_size  uncertain_ratio  \
# 0    2415844636       set           5         10000              0.0
# 1    2415844636       set           5         10000              0.0
# 2    2415844636       set           5         10000              0.0
# 3    2415844636       set           5         10000              0.0
# 4    2415844636       set           5         10000              0.0
# ..          ...       ...         ...           ...              ...
# 85   2415844636       set           5         10000              0.0
# 86   2415844636       set           5         10000              0.0
# 87   2415844636       set           5         10000              0.0
# 88   2415844636       set           5         10000              0.0
# 89   2415844636       set           5         10000              0.0
#
#    interval_size_range mult_size_range  num_intervals  gap_size  \
# 0          (1, 100000)          (1, 5)              1        10
# 1          (1, 100000)          (1, 5)              2        10
# 2          (1, 100000)          (1, 5)              3        10
# 3          (1, 100000)          (1, 5)              4        10
# 4          (1, 100000)          (1, 5)              5        10
# ..                 ...             ...            ...       ...
# 85         (1, 100000)          (1, 5)              6     80000
# 86         (1, 100000)          (1, 5)              7     80000
# 87         (1, 100000)          (1, 5)              8     80000
# 88         (1, 100000)          (1, 5)              9     80000
# 89         (1, 100000)          (1, 5)             10     80000
#
#     interval_width  num_intervals_range gap_size_range interval_width_range  \
# 0              NaN                  NaN       (0, 100)              (2, 15)
# 1              NaN                  NaN       (0, 100)              (2, 15)
# 2              NaN                  NaN       (0, 100)              (2, 15)
# 3              NaN                  NaN       (0, 100)              (2, 15)
# 4              NaN                  NaN       (0, 100)              (2, 15)
# ..             ...                  ...            ...                  ...
# 85             NaN                  NaN       (0, 100)              (2, 15)
# 86             NaN                  NaN       (0, 100)              (2, 15)
# 87             NaN                  NaN       (0, 100)              (2, 15)
# 88             NaN                  NaN       (0, 100)              (2, 15)
# 89             NaN                  NaN       (0, 100)              (2, 15)
#
#    reduce_triggerSz_sizeLim independent_variable  min_time_mean  min_time_std  \
# 0                    (3, 1)        num_intervals         8.4618      0.138780
# 1                    (3, 1)        num_intervals        10.2848      0.208771
# 2                    (3, 1)        num_intervals        12.3400      1.618143
# 3                    (3, 1)        num_intervals        15.9102      7.086417
# 4                    (3, 1)        num_intervals        13.0236      0.365009
# ..                      ...                  ...            ...           ...
# 85                   (3, 1)        num_intervals        11.4726      0.241733
# 86                   (3, 1)        num_intervals        12.1738      1.809192
# 87                   (3, 1)        num_intervals        11.1876      0.087179
# 88                   (3, 1)        num_intervals        11.4570      0.323038
# 89                   (3, 1)        num_intervals        13.8626      5.377967
#
#     max_time_mean  max_time_std  sum_time_mean  sum_time_std  \
# 0          8.6814      0.186700         6.1412      0.102980
# 1          9.9262      0.040538         7.3096      0.098030
# 2         19.7628     14.375074         9.7688      2.503701
# 3         14.6514      3.034908         9.9408      1.843166
# 4         15.7206      5.968528         9.9128      0.242224
# ..            ...           ...            ...           ...
# 85        11.3240      0.293501         7.5018      0.199055
# 86        11.5916      0.483345         7.4378      0.247418
# 87        11.2144      0.131415         7.4054      0.257758
# 88        11.3908      0.310510         7.4032      0.125953
# 89        13.0890      3.924214         7.2062      0.032375
#
#     sumtest_time_mean  sumtest_time_std  reduce_calls_mean  \
# 0              6.0568          0.212005                0.0
# 1              7.4326          0.243763             5000.0
# 2              8.7836          0.656251             9999.0
# 3             10.5044          1.619833             9999.0
# 4             13.8756          7.060203             9999.0
# ..                ...               ...                ...
# 85             7.5614          0.349924             5000.0
# 86             7.3768          0.146797             5000.0
# 87             7.1604          0.100007             5000.0
# 88             7.4538          0.213460             5000.0
# 89             7.4174          0.236889             5000.0
#
#     max_interval_count_mean  total_interval_count_mean  combine_calls_mean  \
# 0                       1.0                    10000.0             10000.0
# 1                       4.0                    30000.0             10000.0
# 2                       9.0                    30006.0             10000.0
# 3                      16.0                    40012.0             10000.0
# 4                      25.0                    50020.0             10000.0
# ..                      ...                        ...                 ...
# 85                      4.0                    30000.0             10000.0
# 86                      4.0                    30000.0             10000.0
# 87                      4.0                    30000.0             10000.0
# 88                      4.0                    30000.0             10000.0
# 89                      4.0                    30000.0             10000.0
#
#     result_size_mean  result_coverage_mean          source_file  \
# 0                1.0               80020.0  ni_gap_red3_1_sweep
# 1                1.0              260422.2  ni_gap_red3_1_sweep
# 2                1.0              440128.6  ni_gap_red3_1_sweep
# 3                1.0              619687.2  ni_gap_red3_1_sweep
# 4                1.0              800419.0  ni_gap_red3_1_sweep
# ..               ...                   ...                  ...
# 85               1.0           800160422.2  ni_gap_red3_1_sweep
# 86               1.0           800160422.2  ni_gap_red3_1_sweep
# 87               1.0           800160422.2  ni_gap_red3_1_sweep
# 88               1.0           800160422.2  ni_gap_red3_1_sweep
# 89               1.0           800160422.2  ni_gap_red3_1_sweep
#
#    gap_size_range_tuple reduce_triggerSz_sizeLim_tuple
# 0              (0, 100)                         (3, 1)
# 1              (0, 100)                         (3, 1)
# 2              (0, 100)                         (3, 1)
# 3              (0, 100)                         (3, 1)
# 4              (0, 100)                         (3, 1)
# ..                  ...                            ...
# 85             (0, 100)                         (3, 1)
# 86             (0, 100)                         (3, 1)
# 87             (0, 100)                         (3, 1)
# 88             (0, 100)                         (3, 1)
# 89             (0, 100)                         (3, 1)
#
# [90 rows x 32 columns]

# %%
gap_params = sorted(df['gap_size'].unique())
# [10, 50, 100, 500, 1000, 10000, 20000, 40000, 80000]
n = len(df['num_intervals'].unique())
fig, axes=  plt.subplots(2, n, figsize=(6*n,6))
for i, ni in enumerate(sorted(df['num_intervals'].unique())):
    df_ni = df[df['num_intervals'] == ni].copy()

    # PLot 1: time
    ax = axes[0, i]
    y = df_ni['sum_time_mean']
    ax.plot(gap_params, y, marker='o')
    ax.set_title(f'ni={ni}')
    ax.set_xlabel('gap_size')
    ax.grid(True)
    ax.set_xscale('log')

    # Plot 2: coverage
    ax = axes[1, i]
    y = df_ni['result_coverage_mean']
    ax.plot(gap_params, y, marker='o')
    ax.set_title(f'ni={ni}')
    ax.set_xlabel('gap_size')
    ax.grid(True)
    ax.set_xscale('log')

axes[0][0].set_ylabel('Time (ms)')
axes[1][0].set_ylabel('Coverage (smaller=better)')
plt.tight_layout()
plt.savefig('./graphics/gapSweepN10k.jpg')
plt.show()

# %%
import seaborn as sns

pivot_time = df.pivot(index='gap_size', columns='num_intervals', values='sum_time_mean')
pivot_cov  = df.pivot(index='gap_size', columns='num_intervals', values='result_coverage_mean')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
sns.heatmap(pivot_time, ax=ax1, cmap='YlOrRd', annot=True, fmt='.1f')
ax1.set_title('Time (ms)')
sns.heatmap(pivot_cov,  ax=ax2, cmap='YlOrRd', annot=False, fmt='.3f')
ax2.set_title('Coverage error')
plt.tight_layout()
plt.show()

# %%
# def plot_3_row_red_vs_TimeNCover(df) -> str:
#         ''' calculates time/cover/distance vs redution params for each ni'''

#         reduce_params = sorted(df['reduce_triggerSz_sizeLim_tuple'].unique())

#         x_labels = [str(r) for r in reduce_params]
#         n = len(df['num_intervals'].unique())

#         # 0: Time vs red params for each ni
#         # 1: Cover vs red params for each ni
#         # 2: Distance = sqrt(time^2 + cover^2)
#         fig, axes=  plt.subplots(3, n, figsize=(6*n,12))
#         for i, ni in enumerate(sorted(df['num_intervals'].unique())):
#             # plot for each ni
#             df_ni = df[df['num_intervals'] == ni].copy()

#             # PLot 1: time
#             ax = axes[0, i]
#             y = df_ni['sum_time_mean']
#             ax.plot(x_labels, y, marker='o')
#             ax.set_title(f'ni={ni}')
#             ax.set_xlabel('red')
#             ax.grid(True)

#             # Plot 2: coverage
#             ax = axes[1, i]
#             y = df_ni['result_coverage_mean']
#             ax.plot(x_labels, y, marker='o')
#             ax.set_title(f'ni={ni}')
#             ax.set_xlabel('red')
#             ax.grid(True)

#             # Plot 3: distance of both time and coverage
#             # normalize time and coverage to equal weight (x-min)/(max-min)
#             df_ni['time_norm'] = safe_normalize(df_ni['sum_time_mean'])
#             df_ni['cov_norm'] = safe_normalize(df_ni['result_coverage_mean'])
#             scores = (df_ni['time_norm']**2 + df_ni['cov_norm']**2)**0.5
            
#             ax = axes[2, i]
#             ax.plot(x_labels, scores, marker='o')
#             ax.set_title(f'ni={ni}')
#             ax.set_xlabel('red')
#             ax.grid(True)
            
#         axes[0][0].set_ylabel('Time (ms)')
#         axes[1][0].set_ylabel('Coverage (smaller=better)')
#         axes[2][0].set_ylabel('Distance (smaller=bettwe)')
        
#         outfile = f'distance_vs_NI_and_red_OG'
#         outpath = f"/Users/asxvi/Desktop/uic/research/audb/extension/experimentRunner/graphics//{outfile}"
#         plt.savefig(outpath, dpi=300, bbox_inches='tight')
#         return outpath
